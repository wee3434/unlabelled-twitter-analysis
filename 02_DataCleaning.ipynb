# %% [markdown]
# Due to the varying and unpredictable nature of language used in social media, data pre-processing is essential to assure the data quality. Five techniques widely used in tweet analysis are implemented.
#
# - Cleaning : words starting with the @ symbol, which refers username. Hypertext markup language (HTML) and a pointer - “#” means hashtags are removed. Emoticons (e.g. 😊, ☹) and un-recognizable UTF-8 encoding forms are converted into human readable words. Converted elongation of words (e.g. cooool, hooooot) to “reducing more than 3 subsequent occurrence of the same repeated character/letter to a sequence of three characters (e.g. coool, hooot)”, which differentiates the regular usage and emphasises the usage of the specific word.
#
#
# - Slangs/abbreviations Correction: convert the most common twitter slangs or abbreviations into the original form of words using tweet slang dictionary.
#
#
# - Tokenisation:  we split each content from the dataset in the corpus with a whitespace to get individual terms, which called token (Grefenstette & Tapanainen, 1994).  Note that short forms like “I’ve”, “can’t” and n-grams created from previous data pre-processing are considered as one word. Other punctuation and special cases are not included in the token list.
#
#
# - Lower casing: unify entire tokens into lower case for consistency.
#
#
# - Stop words Removal: stop words, which can be represented as language specific functional words, like pronouns, prepositions and conjunctions are removed because they don't provide any useful information in text analysis.

# %%
import pandas as pd
import nltk
from nltk.stem import *
from nltk.corpus import sentiwordnet as swn

import re
import numpy as np
import pandas as pd
from pprint import pprint
import csv

# spacy for lemmatization
import spacy

import gensim
import gensim.utils
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer

# %%
# import dataset 
cDF = pd.read_csv("cDMARD_without_URL_TWINTver2.csv")
bDF = pd.read_csv("bDMARD_without_URL_TWINTver2.csv")

# %%
cDF.head()
# Out:
#    Unnamed: 0  index        date                   id  \
# 0           0      1  2018-07-29  1023513962485174273
# 1           1     18  2018-07-19  1019720504821739520
# 2           2     20  2018-07-15  1018422977937850368
# 3           5     33  2018-07-02  1013455474941808640
# 4           7     40  2018-06-24  1010584989573009408
#
#                                                tweet  location     user_id
# 0  Antirheumatic agents (disease modifying): memb...       NaN  1277029087
# 1  @PaolaGhione_MD Methotrexate is still the Gold...       NaN   152868394
# 2  Our desi cow is only being on earth which cont...       NaN  3949709654
# 3  Let's do a poll question! Q2: Gold salts can c...       NaN   511178999
# 4  It was the first meeting after the war and was...       NaN    33488987

# %% [markdown]
# ### cleaning

# %% [markdown]
# ### slangs/abbreviation correction

# %%
def translator(user_string):
    user_string = user_string.split(" ")

    j = 0

    for _str in user_string:
        fileName = "slang2.txt"
        accessMode = "r"

        with open(fileName, accessMode) as myCSVfile:

            # Reading file as CSV with delimiter as "=", so that abbreviation are stored in row[0] and phrases in row[1]

            dataFromFile = csv.reader(myCSVfile, delimiter="=")

            # Removing Special Characters.
            
            _str = re.sub('[^a-zA-Z0-9-_.]', '', _str)
            
            for row in dataFromFile:
                # Check if selected word matches short forms[LHS] in text file.
                if (re.search("\.{1,}", _str)):
                    tmp = re.sub("\.*", "", _str)
                    
                    if tmp.upper() == row[0]:
                   
                    # If match found replace it with its appropriate phrase in text file.
                        user_string[j] = row[1] + "."
                        
                        
                if (re.search("\,{1,}", _str)):
                    tmp = re.sub("\,*", "", _str)
                    
                    if tmp.upper() == row[0]:
                        user_string[j] = row[1] + ","
                        
                
                if _str.upper() == row[0]:
                    # If match found replace it with its appropriate phrase in text file.
                    #print(row[0])
                    #print(row)
                    user_string[j] = row[1]

            myCSVfile.close()

        j = j + 1

    # Replacing commas with spaces for final output.
    return ' '.join(user_string)

# %%
# example of translator 
# tmr, tmrw -> tomorrow 
translator("also... tmr tmrw i got bad hangovers on orencia. i'm hoping that won't b the case withactemra..but idk. kids have early swim meet tmrw &i can't miss it")
# Out:
# "also... Tomorrow  Tomorrow  i got bad hangovers on orencia. i'm hoping that won't Back the case withactemra..but I don't know. kids have early swim meet Tomorrow  &i can't miss it"

# %% [markdown]
# ### tokenisation

# %%
tok = WordPunctTokenizer()

# %%
from nltk.tokenize import word_tokenize

def dataCleaning(df):
    
    for i in range(len(df)):
        temp = df.tweet[i]
        
        # remove HTML 
        soup = BeautifulSoup(temp, 'lxml')
        souped = soup.get_text()
        if(temp != souped):
            print(temp)
            
        #remove mention-username 
        souped = re.sub(r'@[A-Za-z0-9\_\-]+','',souped) 
        souped = re.sub("#", " ", souped) #remeove hashtag=letter only 
        
        # replace repeating character more than 3 times to 3 times     
        souped = re.sub(r'([a-zA-Z])\1{2,}', r'\1\1\1', souped)
        
        #emoticon handling
        souped = re.sub("[;|\:|\=|x|X].?[\)|D]{1,}", " smiling face ", souped)
        souped = re.sub("[;|\:|\=|x|X].?[\(|/]{1,}",  " sad face ", souped)
        souped = re.sub("[;|\:|\=|x|X].?[b|p|P]{1,}", " silly face ", souped)
        souped = re.sub("<3{1,}", "with love", souped)
        souped = re.sub(" w ", " with ", souped)
        
        souped = re.sub("[w|W] {0,1}\/ {0,1}[o|O] ", "without ", souped)
        
        souped = re.sub("[w|W] {0,1}\/","with", souped) 
        souped = re.sub("yr", "year", souped.lower())
        souped = re.sub("yrs", "years", souped.lower())
        
        souped = translator(souped)
        souped = re.sub(" {2,}", " ", souped)        
        df.tweet[i] = souped.strip()

    return df

# %%
cDF.head()
# Out:
#    Unnamed: 0  index        date                   id  \
# 0           0      1  2018-07-29  1023513962485174273
# 1           1     18  2018-07-19  1019720504821739520
# 2           2     20  2018-07-15  1018422977937850368
# 3           5     33  2018-07-02  1013455474941808640
# 4           7     40  2018-06-24  1010584989573009408
#
#                                                tweet  location     user_id
# 0  Antirheumatic agents ( disease modifying ): me...       NaN  1277029087
# 1  Methotrexate is still the Gold Standard Treatm...       NaN   152868394
# 2  Our desi cow is only being on earth which cont...       NaN  3949709654
# 3  Let ' s do a poll question ! Q2 : Gold salts c...       NaN   511178999
# 4  It Wait a second the first meeting after the w...       NaN    33488987

# %%
dataCleaning(cDF)
# Out:
# C:\Users\jennyj\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# @kshevaun_sings @L_Hizzy Best of luck! It works for a lot of people! I personally took methotrexate for as long as I did so I could get insurance to cover my move to biologics. I would ask your doctor about Benlysta, a biologic medicine specifically for lupus.  <URL>
#      Unnamed: 0   index        date                   id  \
# 0             0       1  2018-07-29  1023513962485174273
# 1             1      18  2018-07-19  1019720504821739520
# 2             2      20  2018-07-15  1018422977937850368
# 8    bitch i might go neon white and get injected w...       NaN
# 9    some arthritis medications contain gold salts,...       NaN
# 10   i think i remember learning this in med school...       NaN
# 11   rheumatologists prescribe methotrexate to chil...       NaN
# 12                   i'm intrigued by these gold salts       NaN
# 13   it depends what form it's in. gold leaf itself...       NaN
# 14   drugs associated with producing cvid and iga d...       NaN
# 15   some arthritis medications contain gold salts,...       NaN
# 16   rt sebastianmicozz: 5wrightstuff i had rheumat...       NaN
# 17   indian native breed of cows have a suryaketuna...       NaN
# 18   i had rheumatoid arthritis. i was given 3years...       NaN
# 19   membranous g may also be associated withinfect...       NaN
# 20   in its metallic form, gold is not toxic & is o...       NaN
# 21   assurya ketu nadi interacts with solar rays, g...       NaN
# 22   73. presence of gold salts in cow urine protec...       NaN
# 23   72. cow urine contains many minerals especiall...       NaN
# 24   you're right, it's late. i was thinking of gol...       NaN
# 25   assurya ketu nadi interacts with solar rays, g...       NaN
# 26   are we discussing gold salts? or pure gold nan...       NaN
# 27   cow urine contains many minerals especially co...       NaN
# 28   76.presence of gold salts in cow urine protect...       NaN
# 29   75.cow urine contains many minerals especially...       NaN
# ..                                                 ...       ...
# 473  antimetabolites inhibit cell growth and dna/rn...       NaN
# 474  pediatric age, <6months,non-tbi, cranial irrad...       NaN
# 475  i managed to simultaneously knit & asepticslly...       NaN
# 476  pemetrexed, an analogue of methotrexate,causes...       NaN
# 477  mtx is a good and efficacious starting point. ...       NaN
# 478  chemo is typically given in combinations that ...       NaN
# 479  methotrexate main drug used for this purpose (...       NaN
# 480  all of the following are anti-metabolites exce...       NaN
# 481  and if the latest research be true, mix with d...       NaN
# 482  hopefully. i was wondering about: 1) dlbcl cns...       NaN
# 483  l-asparagine , cytarabine , vincristine & high...       NaN
# 484  our patient's had 2 cycles of hd mtx and cytar...       NaN
# 485  contaminated #cancer rx recalled by fda: gemci...       NaN
# 486  recalls two drugs (gemcitabine and methotrexat...       NaN
# 487  four different cancer injections recalled by $...       NaN
# 488  gemcitabine, carboplatin, methotrexate, and cy...       NaN
# 489  tfw cytarabine, fludarabine, fluorouracil, 6-m...       NaN
# 490  gemcitabine plus cisplatin vs methotrexate, vi...       NaN
# 491  *orderjin ha(14)aml, m6doxorubicin+cyclophosph...       NaN
# 492  day minus 3. long day today. fludarabine and c...       NaN
# 493  adventures in #lymphoma - my partner has had r...       NaN
# 494  it overdose• methotrexate– 22 reported cases i...       NaN
# 495  day full of #chemotherapy : #oxaliplatine #vid...       NaN
# 496  anyone know of the use of the methotrexate-sim...       NaN
# 497  7. methotrexate, pemetrexed, raltitrexed. the ...       NaN
# 498  gemcitabine and cisplatin ; methotrexate, vinb...       NaN
# 499  off to unc pediatric oncology clinic for ara-c...       NaN
# 500  the four drugs involved in hospira recall, the...       NaN
# 501  yep, and now even my little boy knows words "m...       NaN
# 502  1 year ago i'd never heard the words"methotrex...       NaN
#
#                 user_id
# 0            1277029087
# 1             152868394
# 2            3949709654
# 3             511178999
# 4              33488987
# 5    884958231558328321
# 6             184645342
# 7             273390607
# 8    720385476926971908
# 9    988760211476402176
# 25107       67852  127617  2015-11-30   671059315021758464
# 25108       67855  127980  2015-10-24   657681560108408832
# 25109       67863  130077  2015-05-24   602469632792875008
# 25110       67866  130734  2015-04-07   585277102339051520
# 25111       67868  131602  2015-02-23   569603944881610753
# 25112       67887  134716  2014-05-10   464977079948566529
# 25113       67900  135595  2014-03-15   444588151785672704
# 25114       67901  135703  2014-03-07   441634884768239617
# 25115       67921  142317  2013-05-16   335003291517849601
# 25116       67932  143311  2013-03-11   310787330086670336
# 25117       67933  143438  2013-03-03   308132194902220801
# 25118       67934  143440  2013-03-03   308118763650314240
# 25119       67940  143735  2013-02-14   301898597589471232
# 25120       67941  143752  2013-02-13   301380506229035008
# 25121       67944  144149  2013-01-26   294826606625705984
# 25122       67946  144154  2013-01-25   294744041181028353
# 25123       67947  144366  2013-01-20   292703036688699392
# 25124       67956  148460  2012-07-17   225020721028546562
# 25125       67967  151082  2012-02-13   168922111396687873
#
#                                                    tweet  location  \
# 0      staffing problems! apparently i shouldn’t have...       NaN
# 1      it’s a difficult choice. i was stopped because...       NaN
# 2      #myibdhistory told for 7 years had ibs, dx cro...       NaN
# 3      of course. i was on it for eight years. becaus...       NaN
# 4      fingers crossed for the infliximab :crossed_fi...       NaN
# 5      first time out of the house properly in almost...       NaN
# 6      if it's not researched, how do you knowledge i...       NaN
# 7      sorry to hear that gabe. let’s hope that your ...       NaN
# 8      2015 symptoms first started.2016 diagnosed wit...       NaN
# 9      ok. adalimumab is a game changer for people wi...       NaN
# 10     #age14 -stomach pains.#age18 -diagnosed with i...       NaN
# 11     diagnosed with uc age 21, had sub-total colect...       NaN
# 12     is it possible to identify if (for example) : ...       NaN
# 13     thanks lesley for sharing your story. regardin...       NaN
# 14     diag in 2016 age 46 with crohn’s. pred enema, ...       NaN
# 15     #myibdhistory diagnosed march 17 with uc, hosp...       NaN
# 16     #myibdhistory diagnosed with uc at 8years old ...       NaN
# 17     infliximab. the medicine that stops my bowels ...       NaN
# 18     excerpt from article:"first, they brought down...       NaN
# 19     the cost for a patient's adalimumab in louisia...       NaN
# 20     #myibdhistory started at 16; diagnosed at 27. ...       NaN
# 21     hidradenitis suppuritiva - prevalence increasi...       NaN
# 22     premature chris - that is when adalimumab gets...       NaN
# 23     $abbv ceo just said their adalimumab patent se...       NaN
# 24     2/2and i need steroids to short term fix infla...       NaN
# 25     hulio makes 8 discrete adalimumab brands appro...       NaN
# 26     hulio (adalimumab) comes from mylan? assume th...       NaN
# 27     yup, you're right - looks like 5 for both adal...       NaN
# 28     interesting. we looked at this aspect followin...       NaN
# 29     #myibdhistory dx crohns ‘84 (age 7), steroids,...       NaN
# ...                                                  ...       ...
# 25096  .tocilizumab which is an infusion once a mnth ...       NaN
# 25097  how cool! // Retweet .: i am fortunate enough ...       NaN
# 25098  mat pagi, HaveÂ  a great day! smiling face Ret...       NaN
# 25099  mat pagi, HaveÂ  a nice day! smiling face Retw...       NaN
# 25100  i stopped actemra this spring because of hives...       NaN
# 25101  so swollen and ache all over from #rheum- agh-...       NaN
# 25102  crohns is a terrible disease bev, my cousin su...       NaN
# 25103  cost-efficacy of adalimumab, etanercept, infli...       NaN
# 25104  rituximab, bendamustine, and low-dose cytarabi...       NaN
# 25105  cll is treated with fcr(fludarabine, cyclophos...       NaN
# 25106  fda moving things along in the past 24h: gives...       NaN
# 25107  pubmed abstract]. forstpointner are dreyling m...       NaN
# 25108  fludarabine, cyclophosphamide and rituximab ac...       NaN
# 25109  the combination drugs for #cll chemotherapy in...       NaN
# 25110  rituximab starts tonight. content creation des...       NaN
# 25111  waldenstrom’s macroglobulinemia·· further trea...       NaN
# 25112  2 units of cryo, at least 1 unit prbcs, & 3 di...       NaN
# 25113  chronic lymphocytic #leukemia #fludarabine and...       NaN
# 25114  tx of cll: no tx for stage i & ii (elevated wb...       NaN
# 25115  the improving outcome of patients with cll fai...       NaN
# 25116  i just had to say "fludarabine, cyclophosphami...       NaN
# 25117  stuff!" smiling face efinitive: r-fc (rituxima...       NaN
# 25118  definitive: r-fc (rituximab, fludarabine, cycl...       NaN
# 25119  fludarabine, cyclophosphamide, rituxan. best c...       NaN
# 25120  for those that don't knowledge what fcr is-it'...       NaN
# 25121  i have had rituximab with no ill effects. cann...       NaN
# 25122  he asks are you on rituximab? causes neuropath...       NaN
# 25123  now discussing clinical impact of fludarabine,...       NaN
# 25124  cll treatment:fludarabine and rituximab.alemtu...       NaN
# 25125  chronic lymphocytic #leukemia:fludarabine and ...       NaN
#
#             user_id
# 0      2.956904e+08
# 1      2.697912e+08
# 2      2.956904e+08
# 3      3.303199e+09
# 4      2.612927e+08
# 5      1.663716e+09
# 6      7.583030e+17
# 7      4.093497e+08
# 8      3.238341e+08
# 9      7.583030e+17
# 10     6.350064e+08
# 11     2.415758e+08
# 12     9.732971e+17
# 13     3.303199e+09
# 14     2.719361e+08
# 15     7.849679e+08
# 16     3.154027e+08
# 17     3.027418e+08
# 18     2.175600e+09
# 19     2.608120e+09
# 20     1.588118e+08
# 21     7.329719e+07
# 22     1.413590e+09
# 23     2.890487e+08
# 24     7.715784e+07
# 25     2.399825e+08
# 26     2.399825e+08
# 27     6.056577e+08
# 28     1.861858e+09
# 29     3.947741e+08
# ...             ...
# 25096  4.234376e+07
# 25097  1.634839e+08
# 25098  1.170369e+08
# 25099  1.170369e+08
# 25100  1.147889e+08
# 25101  6.071683e+07
# 25102  3.695271e+08
# 25103  3.314944e+08
# 25104  3.884532e+09
# 25105  7.210421e+17
# 25106  2.903559e+07
# 25107  3.085149e+09
# 25108  4.124490e+08
# 25109  3.178183e+09
# 25110  1.583913e+09
# 25111  3.829754e+08
# 25112  4.026148e+07
# 25113  3.829754e+08
# 25114  1.207072e+09
# 25115  1.155427e+08
# 25116  1.553441e+07
# 25117  2.945163e+08
# 25118  2.960851e+08
# 25119  4.123626e+08
# 25120  9.510476e+07
# 25121  1.823988e+08
# 25122  1.669438e+07
# 25123  8.407262e+07
# 25124  2.096656e+07
# 25125  3.829754e+08
#
# [25126 rows x 7 columns]

# %%
#cDF.to_csv("cDMARD without Url after data processing.csv")
bDF.to_csv("bDMARD without URL after data processing ver5.csv")
